# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilrai365/my-website/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# %%
dataset = pd.read_csv('emails.csv')

# %%
dataset = dataset.dropna()

dataset['Category'] = dataset['Category'].map({'spam': 1, 'ham': 0})

# %%
x = dataset['Message']
y = dataset['Category']
print(y.isnull().sum())
print(y.head())
# Out:
# 0
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Category, dtype: int64

# %%
print(y.isnull().sum())
# Out:
# 0

# %%
print(y.isnull())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5567    False
# 5568    False
# 5569    False
# 5570    False
# 5571    False
# Name: Category, Length: 5572, dtype: bool

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state= 42, stratify=y)
vectorizer = TfidfVectorizer(stop_words='english',max_features=5000)
X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

# %%
model = MultinomialNB()
model.fit(X_train_vectorized, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test_vectorized)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9704035874439462
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       966
#            1       1.00      0.78      0.88       149
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.89      0.93      1115
# weighted avg       0.97      0.97      0.97      1115

# %%
def predict_spam(message):
  message_tfidf = vectorizer.transform([message])
  prediction = model.predict(message_tfidf)
  return "Spam" if prediction == 1 else "Ham"

print(predict_spam("Congralutations! You've won a free lottery. Call now!"))
print(predict_spam("Hello, let's meet for lunch today.'"))
# Out:
# Ham
# Ham

# %%
print(dataset["Category"].value_counts())
# Out:
# Category
# 0    4825
# 1     747
# Name: count, dtype: int64

# %%
y_pred = model.predict(vectorizer.transform(X_test))
print("Unique Predictions:", set(y_pred))
# Out:
# Unique Predictions: {0, 1}

# %%
test_message = ["Congratulations! You won a free iPhone! Click here to claim."]
test_message_tfidf = vectorizer.transform(test_message)
print("Prediction:", model.predict(test_message_tfidf))
# Out:
# Prediction: [1]
